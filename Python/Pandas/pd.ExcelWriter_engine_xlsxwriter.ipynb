# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'A': [1, 2, 3],
    'B': [4, 5, 6],
    'C': [7, 8, 9],
})

# %%
path = './data.xlsx'
sheet_name = 'Sheet1'

# %%
value: str = 1

# %%
from xlsxwriter.workbook import Workbook
from xlsxwriter.worksheet import Worksheet

with pd.ExcelWriter(path, engine='xlsxwriter') as writer:
    df.to_excel(writer, sheet_name=sheet_name, index=False)

    workbook: Workbook = writer.book
    worksheet: Worksheet = writer.sheets[sheet_name]

    max_row, max_col = df.shape

    cell_format = workbook.add_format()

    # # Font
    # # 'font_name'
    # cell_format.set_font_name()
    # # 'font_size'
    # cell_format.set_font_size()
    # # 'font_color'
    # cell_format.set_font_color()
    # # 'bold'
    # cell_format.set_bold()
    # # 'italic'
    # cell_format.set_italic()
    # # 'underline'
    # cell_format.set_underline()
    # # 'font_strikeout'
    # cell_format.set_font_strikeout()
    # # 'font_script'
    # cell_format.set_font_script()

    # # Number
    # # 'num_format'
    # cell_format.set_num_format()

    # # Protection
    # # 'locked'
    # cell_format.set_locked()
    # # 'hidden'
    # cell_format.set_hidden()

    # # Alignment
    # # 'align'
    # cell_format.set_align()
    # # 'valign'
    # cell_format.set_valign()
    # # 'rotation'
    # cell_format.set_rotation()
    # # 'text_wrap'
    # cell_format.set_text_wrap()
    # # 'reading_order'
    # cell_format.set_reading_order()
    # # 'text_justlast'
    # cell_format.set_text_justlast()
    # # 'center_across'
    # cell_format.set_center_across()
    # # 'indent'
    # cell_format.set_indent()
    # # 'shrink'
    # cell_format.set_shrink()

    # # Pattern
    # # 'pattern'
    # cell_format.set_pattern()
    # # 'bg_color'
    # cell_format.set_bg_color()
    # # 'fg_color'
    # cell_format.set_fg_color()

    # # Border
    # # 'border'
    # cell_format.set_border()
    # # 'bottom'
    # cell_format.set_bottom()
    # # 'top'
    # cell_format.set_top()
    # # 'left'
    # cell_format.set_left()
    # # 'right'
    # cell_format.set_right()
    # # 'border_color'
    # cell_format.set_border_color()
    # # 'bottom_color'
    # cell_format.set_bottom_color()
    # # 'top_color'
    # cell_format.set_top_color()
    # # 'left_color'
    # cell_format.set_left_color()
    # # 'right_color'
    # cell_format.set_right_color()

    worksheet.set_column(0, max_col - 1, width=20, cell_format=cell_format)
    worksheet.set_row(0, height=20, cell_format=cell_format)
